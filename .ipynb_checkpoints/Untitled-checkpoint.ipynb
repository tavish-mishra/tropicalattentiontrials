# %%
from models import *
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 from models import *
# ----> 2 from dataloaders import *
#       3 import torch
#
# File /global/u2/t/tmishra/Tropical-Attention/dataloaders.py:11
#       9 import bisect
#      10 from typing import List, Tuple
# ---> 11 from quickselect.hoare import nth_smallest, select
#      13 # -------------------------------------------------------------------
#      14 # Set-Based Datasets
#      15 # -------------------------------------------------------------------
#      16 #Given a set of numbers X and a target integer T, the problem is to decide if there exists a subset Y⊆X
#      17 #such that the sum of the elements in Y equals T. An NP-complete problem
#      18 def set_subset_sum_decision(x, T):
#
# ModuleNotFoundError: No module named 'quickselect'

# %%
m = SimpleTransformerModel(d_model=64, n_heads=4, num_layers=4, tropical=True, num_classes=8, activation='relu', 
                           tropical_attention_cls = TropicalAttention(64, 4, torch.device('cuda'))).cuda()

# %%
x = torch.rand((16, 8, 8, 3)).cuda()

# %%
m(x).size()
# Out:
# torch.Size([16, 8, 8])
