# %%
from models import *
import torch

# %%
m = SimpleTransformerModel(d_model=64, n_heads=4, num_layers=4, tropical=True, num_classes=64)

# %%
x = torch.rand((16, 8, 8, 3)).cuda()

# %%
m(x).size()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 m(x).size()
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1740, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1738     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1739 else:
# -> 1740     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1751, in Module._call_impl(self, *args, **kwargs)
#    1746 # If we don't have any hooks, we want to skip the rest of the logic in
#    1747 # this function, and just call forward.
#    1748 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1749         or _global_backward_pre_hooks or _global_backward_hooks
# ...
